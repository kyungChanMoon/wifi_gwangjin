# %%
import pandas as pd

# %%
wifi=pd.read_csv("./dataset/gwangjin_wifi.csv", encoding = 'cp949')
wifi.head()
# Out:
#        관리번호  자치구   와이파이명            도로명주소   상세주소 설치위치(층)            설치유형  \
# 0  ARI00191  광진구  서울물연구원  광진구 천호대로 716-10  본관 1F       1  7-1. 커뮤니티 - 행정
# 1  ARI00192  광진구  서울물연구원  광진구 천호대로 716-10  본관 2F       2  7-1. 커뮤니티 - 행정
# 2  ARI00193  광진구  서울물연구원  광진구 천호대로 716-10  본관 2F       2  7-1. 커뮤니티 - 행정
# 3  ARI00194  광진구  서울물연구원  광진구 천호대로 716-10  본관 2F       2  7-1. 커뮤니티 - 행정
# 4  ARI00195  광진구  서울물연구원  광진구 천호대로 716-10  본관 2F       2  7-1. 커뮤니티 - 행정
#
#       설치기관   서비스구분       망종류  설치년도 실내외구분  wifi접속환경         X좌표     Y좌표  \
# 0  서울시(AP)  공공WiFi  수도사업소자가망  2014    실내       NaN  127.091896  37.547
# 1  서울시(AP)  공공WiFi  수도사업소자가망  2014    실내       NaN  127.091896  37.547
# 2  서울시(AP)  공공WiFi  수도사업소자가망  2014    실내       NaN  127.091896  37.547
# 3  서울시(AP)  공공WiFi  수도사업소자가망  2014    실내       NaN  127.091896  37.547
# 4  서울시(AP)  공공WiFi  수도사업소자가망  2014    실내       NaN  127.091896  37.547
#
#                     작업일자
# 0  2021-10-03 10:57:43.0
# 1  2021-10-03 10:57:43.0
# ...

# %%
wifi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337 entries, 0 to 336
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   관리번호      337 non-null    object
#  1   자치구       337 non-null    object
#  2   와이파이명     337 non-null    object
#  3   도로명주소     337 non-null    object
#  4   상세주소      311 non-null    object
#  5   설치위치(층)   86 non-null     object
#  6   설치유형      337 non-null    object
#  7   설치기관      337 non-null    object
#  8   서비스구분     337 non-null    object
#  9   망종류       337 non-null    object
#  10  설치년도      337 non-null    int64
#  11  실내외구분     337 non-null    object
#  12  wifi접속환경  0 non-null      float64
#  13  X좌표       337 non-null    float64
#  14  Y좌표       337 non-null    float64
#  15  작업일자      337 non-null    object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 42.2+ KB

# %%
wifi.drop(columns=['wifi접속환경'])
# Out:
#          관리번호  자치구        와이파이명             도로명주소   상세주소 설치위치(층)  \
# 0    ARI00191  광진구       서울물연구원   광진구 천호대로 716-10  본관 1F       1
# 1    ARI00192  광진구       서울물연구원   광진구 천호대로 716-10  본관 2F       2
# 2    ARI00193  광진구       서울물연구원   광진구 천호대로 716-10  본관 2F       2
# 3    ARI00194  광진구       서울물연구원   광진구 천호대로 716-10  본관 2F       2
# 4    ARI00195  광진구       서울물연구원   광진구 천호대로 716-10  본관 2F       2
# ..        ...  ...          ...               ...    ...     ...
# 332  WF201229  광진구    워커힐케어센터12    아차산로 634번지 56층      -       -
# 333  WF201230  광진구  광진한울촌노인요양시설       군자로 79(군자동)  프로그램실     NaN
# 334  WF201231  광진구      광진구보훈회관  아차산로 630 345층지하층     복도     NaN
# 335  WF201232  광진구      광진구보훈회관  아차산로 630 345층지하층     복도     NaN
# 336  WF201233  광진구      광진구보훈회관  아차산로 630 345층지하층     복도     NaN
#
#                설치유형      설치기관   서비스구분       망종류  설치년도 실내외구분         X좌표  \
# 0    7-1. 커뮤니티 - 행정   서울시(AP)  공공WiFi  수도사업소자가망  2014    실내  127.091896
# ...

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
map_osm = folium.Map(location = [37.547000, 127.091896], zoom_start=13)
for i in wifi.index:
        folium.CircleMarker([round(wifi['Y좌표'][i],6),round(wifi['X좌표'][i],6)],
                        radius = 3,
                        popup = 'wifi', 
                        color = 'blue', 
                        fill_color = 'blue').add_to(map_osm)
        
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
